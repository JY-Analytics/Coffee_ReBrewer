# %%
import pandas as pd
import numpy as np
import plotly.express as px
from dash import Dash, dcc, html, Input, Output

# %%
df = pd.read_csv("philly_reviews_asba.csv")
df.head(2)
# Out:
#    id             business_id            name        address          city  \
# 0   0  GOSVLhjUT6TnrPhkkmDOpw  Vineyards Cafe  847 N 16th St  Philadelphia
# 1   1  GOSVLhjUT6TnrPhkkmDOpw  Vineyards Cafe  847 N 16th St  Philadelphia
#
#   state  postal_code   latitude  longitude  stars_x  ...  useful  funny cool  \
# 0    PA        19130  39.969939 -75.163026      4.5  ...       0      0    0
# 1    PA        19130  39.969939 -75.163026      4.5  ...       0      0    0
#
#                                          review_text review_date       pss  \
# 0  A great neighborhood cafe! I especially love t...  2019-06-14  0.542547
# 1  this place is so hipster! i ordered crepes whi...  2018-12-10  0.959108
#
#   positive  metric_1  metric_2  composite_score
# 0        1  0.735117      0.82          0.76907
# 1        1  0.735117      0.82          0.76907
#
# [2 rows x 28 columns]

# %%
fig = px.density_mapbox(df, lat = 'latitude', lon = 'longitude', z = 'composite_score',
                        radius = 7,
                        center = dict(lat = 39.99, lon = -75.1),
                        zoom = 10,
                        mapbox_style = 'open-street-map',
                        opacity = 1,
                        color_continuous_scale = 'oranges')
fig.show()
